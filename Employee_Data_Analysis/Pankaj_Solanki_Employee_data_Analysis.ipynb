# %% [markdown]
# ### We will start with employee_survey_data first
# 1. First we will do Univariate Analysis
# 2. then Multivariate Analysis
# 3. Principal Component Analysis

# %% [markdown]
# ### Univariate Analysis

# %%
#import neccessory libraries
import matplotlib.pyplot as plt 
import pandas as pd
import numpy as np
import seaborn as sns
import statistics

# %%
data = pd.read_csv('employee_survey_data.csv')

# %%
data
# Out:
#       EmployeeID  EnvironmentSatisfaction  JobSatisfaction  WorkLifeBalance
# 0              1                      3.0              4.0              2.0
# 1              2                      3.0              2.0              4.0
# 2              3                      2.0              2.0              1.0
# 3              4                      4.0              4.0              3.0
# 4              5                      4.0              1.0              3.0
# ...          ...                      ...              ...              ...
# 4405        4406                      4.0              1.0              3.0
# 4406        4407                      4.0              4.0              3.0
# 4407        4408                      1.0              3.0              3.0
# 4408        4409                      4.0              1.0              3.0
# 4409        4410                      1.0              3.0              NaN
#
# [4410 rows x 4 columns]

# %%
## Removing null values from the data set
data.dropna(inplace=True)

# %%
## finding percentage of missing values in each column
missing_values_percentage = data.isnull().sum() * 100 / len(data)
missing_values_percentage
# Out:
# EmployeeID                 0.0
# EnvironmentSatisfaction    0.0
# JobSatisfaction            0.0
# WorkLifeBalance            0.0
# dtype: float64

# %%
##EnvironmentSatisfaction 
environment_satisfaction = data['EnvironmentSatisfaction'].dropna()

plt.boxplot(environment_satisfaction)
plt.title('Box Plot of Environment Satisfaction')
plt.xlabel('Environment Satisfaction')
plt.ylabel('Satisfaction Level ')

# Display the plot
plt.show()

# %%
environment_satisfaction = data['EnvironmentSatisfaction']

# Calculate mean
mean = environment_satisfaction.mean()

# Calculate median
median = environment_satisfaction.median()

# Calculate mode
mode = statistics.mode(environment_satisfaction)

# Calculate standard deviation
std_dev = environment_satisfaction.std()

print("Mean:", mean)
print("Median:", median)
print("Mode:", mode)
print("Standard Deviation:", std_dev)
# Out:
# Mean: 2.724520452969725
# Median: 3.0
# Mode: 3.0
# Standard Deviation: 1.0929552480687719

# %%
labels = ['Low', 'Medium', 'High', 'Very High']
values = [1,2,3,4]

level_count = [data['EnvironmentSatisfaction'].value_counts()[value] for value in values]

colors = ['#FFB74D', '#FF7043', '#FF5722', '#E64A19']


plt.bar(labels, level_count, color=colors, edgecolor='black', linewidth=1)


plt.title('Distribution of Environment Satisfaction Levels', fontsize=16)
plt.xlabel('Satisfaction Level', fontsize=12)
plt.ylabel('Count', fontsize=12)


plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### Insights
# 1. from the box plot it is clear that no outliear is present in the data setb given
# 2. from bar plot it is clear that more employees are with High Satisfaction level  than Very High Satisfaction level

# %%
environment_satisfaction = data['JobSatisfaction']

# Calculate mean
mean = environment_satisfaction.mean()

# Calculate median
median = environment_satisfaction.median()

# Calculate mode
mode = statistics.mode(environment_satisfaction)

# Calculate standard deviation
std_dev = environment_satisfaction.std()

print("Mean:", mean)
print("Median:", median)
print("Mode:", mode)
print("Standard Deviation:", std_dev)
# Out:
# Mean: 2.7249826669748094
# Median: 3.0
# Mode: 4.0
# Standard Deviation: 1.1014983043535582

# %%
labels = ['Low', 'Medium', 'High', 'Very High']
values = [1,2,3,4]

level_count = [data['JobSatisfaction'].value_counts()[value] for value in values]

colors = ['#FFB74D', '#FF7043', '#FF5722', '#E64A19']


plt.bar(labels, level_count, color=colors, edgecolor='black', linewidth=1)


plt.title('Distribution of Environment Satisfaction Levels', fontsize=16)
plt.xlabel('Job Satisfaction Level', fontsize=12)
plt.ylabel('Count', fontsize=12)


plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# ###### Insights
# 2. from bar plot it is clear that more employees are with Very High Job Satisfaction level than High Satisfaction level

# %%
labels = ['Bad', 'Good', 'Better', 'Best']
values = [1,2,3,4]

level_count = [data['WorkLifeBalance'].value_counts()[value] for value in values]

colors = ['#ccff33', '#f6bd60', '#f28482', '#f95738']


plt.bar(labels, level_count, color=colors, edgecolor='black', linewidth=1)


plt.title('Distribution of Environment Satisfaction Levels', fontsize=16)
plt.xlabel('Work life balance level', fontsize=12)
plt.ylabel('Count', fontsize=12)


plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Insights
# 2. from bor plot it is clear that more employees are with Better  Work Life Balance level than we have Good Work Life Balance level

# %% [markdown]
# ####  multivariate analysis

# %%
selected_columns = ['EnvironmentSatisfaction', 'JobSatisfaction', 'WorkLifeBalance']
selected_data = data[selected_columns]

# Calculate the correlation matrix
correlation_matrix = selected_data.corr()


print("Correlation Matrix:")
print(correlation_matrix.to_string())

plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap="Set3", vmin=-1, vmax=1)
plt.title("Correlation Matrix Heatmap")
plt.show()
# Out:
# Correlation Matrix:
#                          EnvironmentSatisfaction  JobSatisfaction  WorkLifeBalance
# EnvironmentSatisfaction                 1.000000        -0.003998         0.023547
# JobSatisfaction                        -0.003998         1.000000        -0.018055
# WorkLifeBalance                         0.023547        -0.018055         1.000000

# %% [markdown]
# ### Insights
# 1. Environment Satisfaction and Job Satisfaction:
#
# - There is a very weak negative correlation (-0.006550) between Environment Satisfaction and Job Satisfaction.
# - The correlation suggests that there is no significant linear relationship between these two variables.
# - This implies that an increase or decrease in Environment Satisfaction does not necessarily correspond to a similar change in Job Satisfaction.
#
# 2. Environment Satisfaction and Work Life Balance:
#
# - There is a very weak positive correlation (0.024379) between Environment Satisfaction and Work Life Balance.
# - The correlation suggests a minimal tendency for Work Life Balance to slightly increase with higher Environment Satisfaction.
# - However, the correlation is too weak to draw any meaningful conclusions about the relationship between these variables.
#
# 3. Job Satisfaction and Work Life Balance:
#
# - There is a very weak negative correlation (-0.019104) between Job Satisfaction and Work Life Balance.
# - The correlation suggests that there is no clear linear relationship between Job Satisfaction and Work Life Balance.
# - Changes in one variable do not strongly correspond to changes in the other variable.
#
# 4. Overall, the correlation coefficients indicate very weak or negligible correlations among the variables.
#
# - These weak correlations imply that the variables do not strongly influence or depend on each other in a linear manner.

# %% [markdown]
# ###  Principal Component Analysis

# %%
pip install scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.impute import SimpleImputer

# Assuming 'data' is your DataFrame containing the relevant columns
data = data[['EmployeeID', 'EnvironmentSatisfaction', 'JobSatisfaction', 'WorkLifeBalance']]

# Drop any rows with missing values
data = data.dropna()

# Select the columns for PCA
columns_for_pca = ['EnvironmentSatisfaction', 'JobSatisfaction', 'WorkLifeBalance']

# Standardize the data
data_standardized = (data[columns_for_pca] - data[columns_for_pca].mean()) / data[columns_for_pca].std()

# Impute missing values (if any)
imputer = SimpleImputer(strategy='mean')
data_imputed = imputer.fit_transform(data_standardized)

# Instantiate PCA object
pca = PCA()

# Fit PCA model
pca.fit(data_imputed)

# Obtain principal components
principal_components = pca.transform(data_imputed)

# Create a DataFrame to store the results
pca_results = pd.DataFrame(data=principal_components, columns=['PC1', 'PC2', 'PC3'])

# Add EmployeeID to the results DataFrame
pca_results['EmployeeID'] = data['EmployeeID']

# Print explained variance ratio
explained_variance_ratio = pca.explained_variance_ratio_
print("Explained Variance Ratio:", explained_variance_ratio)
print()

# Display the results
print("Principal Components:")
print(pca_results)
# Out:
# Explained Variance Ratio: [0.34389389 0.33204802 0.32405809]
#
# Principal Components:
#            PC1       PC2       PC3  EmployeeID
# 0     1.127015 -1.034654  0.472334         1.0
# 1    -1.643393  0.308167 -0.877728         2.0
# 2     1.774879  1.014583  1.703545         3.0
# 3    -0.357723 -1.638749 -0.046132         4.0
# 4    -1.613033  0.528964  1.022985         5.0
# ...        ...       ...       ...         ...
# 4322  0.160248 -1.085815 -0.559069      4323.0
# 4323 -1.613033  0.528964  1.022985      4324.0
# 4324 -0.357723 -1.638749 -0.046132      4325.0
# 4325  0.777752  0.742625 -1.228572      4326.0
# 4326 -1.613033  0.528964  1.022985      4327.0
#
# [4327 rows x 4 columns]

# %% [markdown]
# ### Now we will Analyse manager_survey_data

# %%
data_manager = pd.read_csv('manager_survey_data.csv')

# %%
data_manager
# Out:
#       EmployeeID  JobInvolvement  PerformanceRating
# 0              1               3                  3
# 1              2               2                  4
# 2              3               3                  3
# 3              4               2                  3
# 4              5               3                  3
# ...          ...             ...                ...
# 4405        4406               3                  3
# 4406        4407               2                  3
# 4407        4408               3                  4
# 4408        4409               2                  3
# 4409        4410               4                  3
#
# [4410 rows x 3 columns]

# %%
## Removing null values from the data set
data_manager.dropna(inplace=True)

# %%
## finding percentage of missing values in each column
missing_values_percentage = data_manager.isnull().sum() * 100 / len(data)
missing_values_percentage
# Out:
# EmployeeID           0.0
# JobInvolvement       0.0
# PerformanceRating    0.0
# dtype: float64

# %%
job_involvement = data_manager['JobInvolvement']

plt.hist(job_involvement, bins=4, edgecolor='black')
plt.xlabel('Job Involvement Level')
plt.ylabel('Frequency')
plt.title('Distribution of Job Involvement')
plt.show()

# %%
job_involvement = data_manager['JobInvolvement']
plt.boxplot(job_involvement)
plt.ylabel('Job Involvement Level')
plt.title('Box Plot - Job Involvement')
plt.show()

# %% [markdown]
# ### From Above Two Plots
#    1.  it suggests that the JobInvolvement levels are not evenly distributed.
#    2. a median value of 3.0 suggests that approximately half of the individuals in the dataset have a JobInvolvement level below 3.0, while the other half have a level above 3.0.
#    3. and there is no outlier in the job involvemment

# %%
labels = ['Low', 'Medium', 'High', 'Very High']
values = [1,2,3,4]

level_count = [data_manager['JobInvolvement'].value_counts()[value] for value in values]

colors = ['#FFB74D', '#FF7043', '#FF5722', '#E64A19']


plt.bar(labels, level_count, color=colors, edgecolor='black', linewidth=1)


plt.title('Distribution of Job Involvement Levels', fontsize=16)
plt.xlabel('Job Involvement Level', fontsize=12)
plt.ylabel('Count', fontsize=12)


plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### from above graph it is clear that People is Higly and Mediumly  involved in jobs

# %%
labels = ['Low', 'Good', 'Excellent', 'Outstanding']
values = [1, 2, 3, 4]


value_set = set(values)

level_count = [data_manager['PerformanceRating'].value_counts().get(value, 0) for value in value_set]

colors = ['#ccff33', '#f6bd60', '#f28482', '#f95738']

plt.bar(labels, level_count, color=colors, edgecolor='black', linewidth=1)

plt.title('Distribution of Performance Rating', fontsize=16)
plt.xlabel('Performance Rating level', fontsize=12)
plt.ylabel('Count', fontsize=12)

plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# ####
# - From the Above Plotted graph is clear that there no member with performance rating  Low (1) and Good(2)
# - and most of the member have Excellent Performance Rating and Few of them are outstanding(approx 600)

# %% [markdown]
# #### Multivariant Analysis

# %%
selected_columns = ['JobInvolvement', 'PerformanceRating']
selected_data = data_manager[selected_columns]

# Calculate the correlation matrix
correlation_matrix = selected_data.corr()


print("Correlation Matrix:")
print(correlation_matrix.to_string())

plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap="Accent", vmin=-1, vmax=1)
plt.title("Correlation Matrix Heatmap")
plt.show()
# Out:
# Correlation Matrix:
#                    JobInvolvement  PerformanceRating
# JobInvolvement           1.000000           0.010699
# PerformanceRating        0.010699           1.000000

# %% [markdown]
# ####
# - Weak correlation: The correlation coefficient between "JobInvolvement" and "PerformanceRating" is very low (0.010699), indicating a weak positive correlation. This means that there is little to no linear relationship between an employee's job involvement level and their performance rating.

# %% [markdown]
# #### Now we will analyse general_data

# %%
## read the data 
general_data = pd.read_csv('general_data.csv')

# %%
general_data
# Out:
#       Age Attrition     BusinessTravel              Department
# 0      51        No      Travel_Rarely                   Sales  \
# 1      31       Yes  Travel_Frequently  Research & Development
# 2      32        No  Travel_Frequently  Research & Development
# 3      38        No         Non-Travel  Research & Development
# 4      32        No      Travel_Rarely  Research & Development
# ...   ...       ...                ...                     ...
# 4405   42        No      Travel_Rarely  Research & Development
# 4406   29        No      Travel_Rarely  Research & Development
# 4407   25        No      Travel_Rarely  Research & Development
# 4408   42        No      Travel_Rarely                   Sales
# 4409   40        No      Travel_Rarely  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  EmployeeID
# 0                    6          2  Life Sciences              1           1  \
# ...

# %%
## finding percentage of missing values in each column
missing_values_percentage = general_data.isnull().sum() * 100 / len(general_data)
missing_values_percentage
# Out:
# Age                        0.000000
# Attrition                  0.000000
# BusinessTravel             0.000000
# Department                 0.000000
# DistanceFromHome           0.000000
# Education                  0.000000
# EducationField             0.000000
# EmployeeCount              0.000000
# EmployeeID                 0.000000
# Gender                     0.000000
# JobLevel                   0.000000
# JobRole                    0.000000
# MaritalStatus              0.000000
# MonthlyIncome              0.000000
# NumCompaniesWorked         0.430839
# Over18                     0.000000
# PercentSalaryHike          0.000000
# StandardHours              0.000000
# StockOptionLevel           0.000000
# TotalWorkingYears          0.204082
# TrainingTimesLastYear      0.000000
# YearsAtCompany             0.000000
# YearsSinceLastPromotion    0.000000
# YearsWithCurrManager       0.000000
# dtype: float64

# %%
## Removing null values from the data set
general_data.dropna(inplace=True)

# %%
##data after removing missing values
missing_values_percentage = general_data.isnull().sum() * 100 / len(general_data)
missing_values_percentage
# Out:
# Age                        0.0
# Attrition                  0.0
# BusinessTravel             0.0
# Department                 0.0
# DistanceFromHome           0.0
# Education                  0.0
# EducationField             0.0
# EmployeeCount              0.0
# EmployeeID                 0.0
# Gender                     0.0
# JobLevel                   0.0
# JobRole                    0.0
# MaritalStatus              0.0
# MonthlyIncome              0.0
# NumCompaniesWorked         0.0
# Over18                     0.0
# PercentSalaryHike          0.0
# StandardHours              0.0
# StockOptionLevel           0.0
# TotalWorkingYears          0.0
# TrainingTimesLastYear      0.0
# YearsAtCompany             0.0
# YearsSinceLastPromotion    0.0
# YearsWithCurrManager       0.0
# dtype: float64

# %%
age = general_data['Age']

# Calculate mean
mean = age.mean()

# Calculate median
median = age.median()

# Calculate mode
mode = statistics.mode(age)

# Calculate standard deviation
std_dev = age.std()

print("Mean:", mean)
print("Median:", median)
print("Mode:", mode)
print("Standard Deviation:", std_dev)
# Out:
# Mean: 36.933363760839796
# Median: 36.0
# Mode: 35
# Standard Deviation: 9.137271912839633

# %% [markdown]
# #
# 1. Mean: 36.93 : it indicates that the average age of the employees is approximately 36.93 years.
# 2. Median: 36.0: This means that half of the employees have an age of 36 or below, and the other half have an age of 36 or above.
# 3. Mode: 35: indicating that 35 years old is the most common age among the employees.

# %%
less = len(general_data[general_data['Age']< 35])
equal = len(general_data[general_data['Age']== 35])
more = len(general_data[general_data['Age']>35])

total_count = less+more+more

percent_less = (less/total_count)*100
percent_equal = (equal/total_count)*100
percent_more = (more/total_count)*100

categories = ['<35 Years','=35 Years','>35 Years']
percentages =  [percent_less,percent_equal,percent_more]

colors = ['#ccff33', '#f6bd60', '#f28482', '#f95738']

plt.bar(categories,percentages,color=colors, edgecolor='black', linewidth=1)
plt.xlabel('Age Category',fontsize=12)
plt.ylabel('Percentage of People',fontsize=12)
plt.title('Percentage of People in Different Age Categories',fontsize=16)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.tight_layout()
# Display the plot
plt.show()

# %% [markdown]
# #
# - About 35% of the total employee working have age greater than 35 years
# - About 31% of the total employee working have age less than 35 years

# %%
# Calculate the count or percentage of attrition values
attrition_counts = general_data['Attrition'].value_counts()
labels = attrition_counts.index
sizes = attrition_counts.values

# Create the pie plot
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90)
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle

# Add a title
plt.title('Attrition: Employees Left vs. Currently Working')

# Display the plot
plt.show()

# %% [markdown]
# #
# - about 16.1% of the total employee has left last year
# - and about 83.9% are still working with company

# %%
# Calculate the count or percentage of attrition values
department_counts = general_data['Department'].value_counts()
labels = department_counts.index
sizes = department_counts.values

# Create the pie plot
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=45)
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle

# Add a title
plt.title('Employee In Departements')

# Display the plot
plt.show()

# %% [markdown]
# #
# - out of total employees about 4.3% employee are working in HR Departmemnt which is least
# - R&D has the highest percentage of employee anout 65.4%
# - and Sales department has about 30.4 % employee
#                                                                       --- Hence R&D is largest holder of employee

# %%
labels = ['Below College', 'College', 'Bachelor', 'Master','Doctor']
values = [1,2,3,4,5]

value_set = set(values)

level_count = [general_data['Education'].value_counts().get(value, 0) for value in value_set]

colors = ['#ccff33', '#f6bd60', '#f28482', '#f95738', '#f35985']

plt.bar(labels, level_count, color=colors, edgecolor='black', linewidth=1)

plt.title('Distribution of Educatiob Level', fontsize=16)
plt.xlabel('Performance Rating level', fontsize=12)
plt.ylabel('Count', fontsize=12)

plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# #
# - most the employee working are with Bachelor's and Master's Degree and most of them has done theire college
# - A few number of employee are Below College about 500 employee
# - and some the employee also hav the Doctor's Degree

# %%
gender_count = general_data['Gender'].value_counts()
labels = gender_count.index
sizes = gender_count.values

colors = ['#ccff33', '#f6bd60']
explode = (0,0.1)
# Create the pie plot
patches, texts, _ = plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90, colors=colors, explode=explode)

# Add an outline to the pie chart
for patch in patches:
    patch.set_edgecolor('black')

# Add a title
plt.title('Division Male and Female Employees')

# Display the plot
plt.show()

# %% [markdown]
# #
# - about 60% workforce is Male and 40% is Female

# %%
age = general_data['MonthlyIncome']
total_salary = general_data['MonthlyIncome'].sum()


# Calculate mean
mean = age.mean()

# Calculate median
median = age.median()

# Calculate mode
mode = statistics.mode(age)

# Calculate standard deviation
std_dev = age.std()

print("Mean:", mean)
print("Median:", median)
print("Mode:", mode)
print("Standard Deviation:", std_dev)
print("Total Amount Given as Salary:", total_salary)
# Out:
# Mean: 65061.702418986766
# Median: 49190.0
# Mode: 23420
# Standard Deviation: 47142.31017515987
# Total Amount Given as Salary: 285100380

# %% [markdown]
# #
# 1. Mean: The mean (average) monthly income is approximately 65,061.70.
# 2. Median: The median monthly income is 49,190.0. This is the middle value when all the monthly incomes are arranged in ascending order.
# 3. The mode of the "monthlyincome" column is 23,420.This indicates that a significant number of individuals have a monthly income of 23,420.
# 4. Total Amount Given as Salary: The total amount paid as salary in the dataset is 285,100,380.  It represents the overall amount of money paid as salaries to the Employees in the dataset.

# %%
less = len(general_data[general_data['TotalWorkingYears']< 10])
equal = len(general_data[general_data['TotalWorkingYears']== 10])
more = len(general_data[general_data['TotalWorkingYears']>10])

total_count = less+more+more

percent_less = (less/total_count)*100
percent_equal = (equal/total_count)*100
percent_more = (more/total_count)*100

categories = ['<10 Years','=10 Years','>10 Years']
percentages =  [percent_less,percent_equal,percent_more]

colors = ['#f6bd60', '#f28482', '#f95738']

plt.bar(categories,percentages,color=colors, edgecolor='black', linewidth=1)
plt.xlabel('Years Worked',fontsize=12)
plt.ylabel('Percentage of People',fontsize=12)
plt.title('Percentage of People in Different Working Years Categories',fontsize=16)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.tight_layout()
# Display the plot
plt.show()

# %% [markdown]
# #
# - from above graph it's clear that most of the employee has worked less than 10 years about 40%
# - but it is also impressive that about 30% employee has worked  for the company more than 10 years and reset are equivalent to 10 years

# %% [markdown]
# ### Multivarient Analysis

# %%
attrition_counts = general_data['Attrition'].value_counts()
attrition_percentages = attrition_counts / len(general_data) * 100

# Bar plot of attrition levels
plt.figure(figsize=(8, 6))
plt.style.use('seaborn')  
colors = ['steelblue','orange']
attrition_percentages.plot(kind='bar', color=colors,edgecolor='black', linewidth=1)  
plt.xlabel('Attrition',fontsize=12)
plt.ylabel('Percentage',fontsize=12)
plt.title('Attrition Levels',fontsize=16)
plt.xticks(rotation=0)  
plt.gca().yaxis.grid(True)  
plt.tight_layout() 
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_10956\3430710782.py:6: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %%
# Relationship between attrition and age
plt.figure(figsize=(8, 6))
plt.hist([general_data[general_data['Attrition'] == 'Yes']['Age'], general_data[general_data['Attrition'] == 'No']['Age']],
         bins=20, stacked=True, label=['Attrition: Yes', 'Attrition: No'],edgecolor='black', linewidth=1)
plt.xlabel('Age',fontsize=12)
plt.ylabel('Count',fontsize=12)
plt.title('Distribution of Age for Attrition Levels',fontsize=16)
plt.legend()
plt.show()

# %% [markdown]
# #### from Above graph Insights are as follow:
# - Age group between 40 to 60 years has very low atttrition rate this could be due to high job levels and higher salaries
# - Age group between 30 to 35 has significantly high attrition Rate

# %%
# Relationship between attrition and job level
job_level_counts = general_data[general_data['Attrition'] == 'Yes']['JobLevel'].value_counts().sort_index()
job_level_percentages = job_level_counts / attrition_counts['Yes'] * 100

plt.figure(figsize=(8, 6))
job_level_percentages.plot(kind='bar',edgecolor='black', linewidth=1)
plt.xlabel('Job Level',fontsize=12)
plt.ylabel('Percentage',fontsize=12)
plt.title('Attrition by Job Level',fontsize=16)
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# #### From Relation we have following insights
# - high job level like 4 - has low attrition rate
# - low levels like 1 -2 have significantly high attrition rate this could be due less Slary hikes, less Salary etc

# %%
# Relationship between attrition and department
department_counts = general_data['Department'].value_counts()

plt.figure(figsize=(8, 6))
attrition_by_department = general_data[general_data['Attrition'] == 'Yes']['Department'].value_counts()
attrition_by_department.plot(kind='bar',edgecolor='black', linewidth=1)
plt.xlabel('Department',fontsize=12)
plt.ylabel('Count',fontsize=12)
plt.title('Attrition by Department',fontsize=16)
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# #
# - R&D Department  has the highest attrition rate which means R&D has most level 1 and level 2 employees
# - HR Department has least attrition rate which means it include high job levels and have better salary opportunities

# %%
# Relationship between attrition and education level
education_counts = general_data['Education'].value_counts()

plt.figure(figsize=(8, 6))
attrition_by_education = general_data[general_data['Attrition'] == 'Yes']['Education'].value_counts()
attrition_by_education.plot(kind='bar',edgecolor='black', linewidth=1)
plt.xlabel('Education Level')
plt.ylabel('Count')
plt.title('Attrition by Education Level')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# #### From above Graph:
# - Bachelors are the one who have large attrition rate while Doctors has least attrition rate
# - second attrition is from master's degree
# - below college employee has less attrition rate this could be due they have less skills and want to gain experience

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Merge the two dataframes based on EmployeeNumber
merged_df = pd.merge(general_data, data, on='EmployeeID')

# Calculate average job satisfaction by gender
average_job_satisfaction = merged_df.groupby('Gender')['JobSatisfaction'].mean().reset_index()

# Relationship between Gender and Job Satisfaction
plt.figure(figsize=(8, 6))
sns.barplot(x='Gender', y='JobSatisfaction', data=merged_df,edgecolor='black', linewidth=1)
plt.xlabel('Gender',fontsize=12)
plt.ylabel('Job Satisfaction',fontsize=12)
plt.title('Job Satisfaction by Gender',fontsize=16)

# Display job satisfaction level on each bar
for index, row in average_job_satisfaction.iterrows():
    plt.annotate(f"{row['JobSatisfaction']:.2f}", xy=(row.name, row['JobSatisfaction']), ha='center', va='bottom')

plt.yticks([0, 1,2,3], ['1', '2','3','4'])    
plt.show()

# %%
# Create a box plot to visualize the relationship between performance rating and training opportunities

merged_data = pd.merge(general_data, data_manager, on='EmployeeID')
sns.boxplot(x='PerformanceRating', y='TrainingTimesLastYear', data=merged_data)
plt.xlabel('Performance Rating')
plt.ylabel('Training Times Last Year')
plt.title('Relationship between Performance Rating and Training Opportunities')
plt.show()

# %% [markdown]
# ### Insights are:
# - Training Opportunities and Performance Rating: The box plot shows that employees with performance ratings of 3 and 4 have similar median values for training times last year. This suggests that the number of training opportunities provided to employees does not vary significantly based on their performance ratings
# - Limited Variability: The boxes for both performance ratings 3 and 4 are of the same size, indicating that the interquartile ranges (IQR) are similar. This suggests that the spread of training times last year is consistent across employees with different performance ratings.
# - Outliers: The solid-filled dots above the boxes, at y-axis values 5 and 6, represent outliers. These outliers indicate that there are a few employees who received a relatively higher number of training opportunities compared to others, regardless of their performance rating.
# - Lack of Training: The solid-filled dot below the box, at y-axis value 0, suggests that some employees received no training opportunities last year. This highlights a potential area for improvement in the organization's training practices, as offering training to all employees can contribute to their skill development and job performance.

# %%
merged_data = pd.merge(data, data_manager, on='EmployeeID')

# Create a box plot to visualize the relationship between PerformanceRating and EnvironmentSatisfaction
sns.boxplot(x='PerformanceRating', y='EnvironmentSatisfaction', data=merged_data)
plt.xlabel('Performance Rating')
plt.ylabel('Work Environment Satisfaction')
plt.title('Relationship between Performance Rating and Work Environment Satisfaction')
plt.show()

# %% [markdown]
# ### Insights are:
# - Work Environment Satisfaction Level:  This indicates that the median work environment satisfaction level is similar for both performance ratings.
# - This means that employees with different performance ratings experience a similar range of work environment satisfaction levels.
# - Overall Satisfaction: The boxes for both Performance Ratings 3 and 4 span from approximately 2.0 to 4.0 on the y-axis. This indicates that employees with these performance ratings have varying levels of work environment satisfaction, ranging from relatively low to relatively high.
# -

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Assuming your dataset is stored in a pandas DataFrame called 'df'
# And the columns 'YearsSinceLastPromotion' and 'Education' exist

# Group the data by education level and extract the 'YearsSinceLastPromotion' column
grouped_data = general_data.groupby('Education')['YearsSinceLastPromotion'].apply(list)

# Create a list of education levels in the dataset
education_levels = general_data['Education'].unique()

# Create a list of years since last promotion for each education level
data = [grouped_data[level] for level in education_levels]

# Plotting the boxplot
plt.figure(figsize=(10, 6))
plt.boxplot(data, labels=education_levels)

# Add labels and title to the plot
plt.xlabel('Education Level')
plt.ylabel('Years Since Last Promotion')
plt.title('Years Since Last Promotion by Education Level')

# Show the plot
plt.show()

# %% [markdown]
# #
# - education level below college and master has more number of employee who  have experienced unusually long periods without a promotion compared to the majority of employees in their respective education levels.
# - Employees with a higher education level (e.g., master's or doctorate) tend to have a wider spread of years since their last promotion compared to those with lower education levels (e.g., below college or college). This suggests that higher education does not necessarily guarantee more frequent promotions.

# %%
Age = general_data['Age']
MonthlyIncome = general_data['MonthlyIncome']


plt.style.use('seaborn')


plt.scatter(Age, MonthlyIncome, color='blue', alpha=0.7)


plt.xlabel('Age')
plt.ylabel('Salary')
plt.title('Salary vs Age')


plt.grid(True, linestyle='--', alpha=0.5)


plt.gca().set_facecolor('#F2F2F2')


plt.xticks(fontsize=10)
plt.yticks(fontsize=10)


plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_10956\3428036711.py:5: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %% [markdown]
# #
# - Age group of 30 to 40 has highest range of monthly Salary

# %%
Salary = general_data['MonthlyIncome']
experience = general_data['TrainingTimesLastYear']

plt.figure(figsize=(8, 6))  # Set the figure size
plt.scatter(experience, Salary, s=50, alpha=0.5, color='b')  # Set the marker size, transparency, and color

plt.xlabel('Years of Experience', fontsize=12)  # Set the x-axis label and font size
plt.ylabel('Salary', fontsize=12)  # Set the y-axis label and font size
plt.title('Salary vs Years of Experience', fontsize=14)  # Set the title and font size

plt.grid(True)  # Add grid lines
plt.tight_layout()  # Adjust the spacing between subplots

plt.show()

# %%
distance_from_home = general_data['DistanceFromHome']
salary = general_data['MonthlyIncome']

# Creating a scatter plot
plt.figure(figsize=(10, 6))  # Adjust the figure size as needed
plt.scatter(distance_from_home, salary, color='steelblue', alpha=0.5)
plt.xlabel('Distance from Home', fontsize=12)
plt.ylabel('Salary', fontsize=12)
plt.title('Salary vs Distance from Home', fontsize=14)
plt.grid(True)  # Add gridlines for better
plt.tight_layout()  # Adjust the spacing between subplots

plt.show()

# %% [markdown]
# #
# - Distance From Home ahs no significant effect on Salary
